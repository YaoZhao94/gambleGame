# %%
playerOneArmy = []
playerOneMedics = 0
playerTwoArmy = []
playerTwoMedics = 0
army = []
playerNumber = 1

while playerNumber <3:
    if playerNumber == 1:
        playerOneName = ""
        while not playerOneName:
            playerOneName = input ("Hello, player One, Please enter your name: ")
        print ("Hello," + playerOneName + ", you have a total of $10 in your pocket")
    else:
        playerTwoName = ""
        while not playerTwoName:
            playerTwoName = input ("Hello, player Two, Please enter your name: ")
        print ("Hello," + playerTwoName + ", you have a total of $10 in your pocket")
    print ("")
    print ("")
    print ("_________________________________________________________________________________________")
    print ("|                                      Instruction                                      |")
    print ("| Units are purchased and stored in your army                                           |")
    print ("| At least you need to purchase one unit for your army.                                 |")
    print ("| You can purchase 3 kind of units: Archer, Soldier and Knight                          |")
    print ("| Archers are good against Soldiers but are terrible against Knights.                   |")
    print ("| Soldiers are good against Knights but can’t win against Archers.                      |")
    print ("| Knights beat Archers, but fall short against Soldiers.                                |")
    print ("| The winning matrix                                                                    |")
    print ("|                      ___________________________________________                      |")
    print ("|                      |Type of Unit | Archer | Soldier | Knight |                      |")
    print ("|                      |_____________|________|_________|________|                      |")
    print ("|                      |   Archer    |   Tie  | Archer  | Knight |                      |")
    print ("|                      |   Soldier   | Archer |   Tie   | Soldier|                      |")
    print ("|                      |   Knight    | Knight | Soldier |   Tie  |                      |")
    print ("|                      |_____________|________|_________|________|                      |")
    print ("| Different have different health                                                       |")
    print ("| Knights have 3 health, Soldiers have 2 and Archers have 1                             |")
    print ("| Each unit now deals damage based on who they have an advantage over.                  |")
    print ("| If the unit has the advantage, they deal 3 damage,                                    |")
    print ("| if the unit has the disadvantage, they deal 1,                                        |")
    print ("| and if the unit has no advantage or disadvantage, they deal 2.                        |")
    print ("| The price of the unit is same to its health                                           |")
    print ("| Money remaining after the purchasing of armies will be used to hire and outfit medics |")
    print ("| When a unit dies, it will be returned to the pool at the back of the army.            |")
    print ("| Each time this happens, supplies for the medics decreases.                            |")
    print ("| The amount of medics decrease will relate to the health of unit                       |")
    print ("| If the medics left less than the full health of the unit, the unit will die.          |")
    print ("| The left medics will retained until it can cover the full health of one unit.         |")
    print ("| Medics are hired and supplied at $1 per unit.                                         |")
    print ("|_______________________________________________________________________________________|")
    print ("")
    print ("")
    interaction = 0
    sequence = 1
    pocket = 10
    army = []
    while interaction != "4" and pocket > -1:
        if pocket == 0:
            if playerNumber == 1:
                playerOneArmy = army
                print ("_____________________________________________________________")
                print (playerOneName + "'s army:")
                print (playerOneArmy)
                print ("There will be " + str(pocket) + " medics")
                print ("_____________________________________________________________")
                break
            else:
                playerTwoArmy = army
                print ("_____________________________________________________________")
                print (playerTwoName + "'s army:")
                print (playerTwoArmy)
                print ("There will be " + str(pocket) + " medics")
                print ("_____________________________________________________________")
                break
            
        print ("Money left in your pocket: " + str(pocket))
        print ("Please pick the " + str(sequence) + " unit:")
        print ("1.archer")
        print ("2.soldier")
        print ("3.knight")
        print ("4.Exit")
        print ("")
        interaction = input ()
        while interaction == "4" and not army:
            print ("Please choose at least one unit")
            interaction = input ()
            
        if interaction == "1" and pocket >= 1:
            army.append(['archer', 1, 1])
            sequence += 1
            pocket -= 1
        elif interaction == "2" and pocket >= 2:
            army.append(['soldier', 2, 2])
            sequence += 1
            pocket -= 2
        elif interaction == "3" and pocket >= 3:
            army.append(['knight', 3, 3])
            sequence += 1
            pocket -= 3
        elif interaction == "4":
            if playerNumber == 1:
                playerOneArmy = army
                playerOneMedics = pocket
                print ("_____________________________________________________________")
                print (playerOneName + "'s army:")
                print (playerOneArmy)
                print ("There will be " + str(pocket) + " medics")
                print ("_____________________________________________________________")
                break
            else:
                playerTwoArmy = army
                playerTwoMedics = pocket
                print ("_____________________________________________________________")
                print (playerTwoName + "'s army:")
                print (playerTwoArmy)
                print ("There will be " + str(pocket) + " medics")
                print ("_____________________________________________________________")
                break
        else:
            print ("____________________________")
            print ("Please select a valid number")
            print ("____________________________")
            
    playerNumber += 1
    

a = 0
i = 0
while a < len(playerOneArmy) and i < len(playerTwoArmy):
    armyPool = [['archer', 1, 1], ['soldier', 2, 2], ['knight', 3, 3]]
    g = 0
    if playerOneArmy [a][2] - playerTwoArmy [i][2] == -1 or playerOneArmy [a][2] - playerTwoArmy [i][2] == 2:
        print ("_____________________________________________________________")
        print ("|                      Battle Ground                        |")
        print ("_____________________________________________________________")
        print (str(playerOneArmy[a]) + " VS " + str(playerTwoArmy[i]))
        print ("")
        print ("")
        
        while g < 3:
            if playerOneArmy [a][2] != armyPool[g][2]:
                print ("g1 run" + str(g))
                g += 1
                
            else:
                print (str(playerOneArmy [a]) + " -1 health")
                playerOneArmy [a][1] = playerOneArmy [a][1] - 1
                if playerOneArmy [a][1] <= 0:
                    print (str(playerOneArmy [a]) + "dead")
                    if playerOneMedics >= playerOneArmy [a][2]:
                        playerOneArmy.append(armyPool[g])
                        playerOneMedics -= playerOneArmy [a][2]
                        print ("+++++++++++++++++++++++++")
                        print ("+Unit is saved by medics+")
                        print ("+Medics left: " + str(playerOneMedics) + "         +")
                        print ("+++++++++++++++++++++++++")
                        a += 1
                    else:
                        a += 1
                else:
                    print (str(playerOneArmy [a]) + "still alive")
                
                print (str(playerTwoArmy [i]) + " -3 health")
                playerTwoArmy [i][1] = 0
                print (str(playerTwoArmy [i]) + "dead")
                if playerTwoMedics >= playerTwoArmy [i][2]:
                    playerTwoArmy.append(armyPool[(g+1)%3])
                    playerTwoMedics -= playerTwoArmy [i][2]
                    print ("+++++++++++++++++++++++++")
                    print ("+Unit is saved by medics+")
                    print ("+Medics left: " + str(playerTwoMedics) + "        +")
                    print ("+++++++++++++++++++++++++")
                    i += 1
                else:
                    i += 1
                break
            
        print ("Player One" + playerOneName + "'s army left:")
        print (playerOneArmy [a:])
        print ("Player Two" + playerTwoName + "'s army left:")
        print (playerTwoArmy [i:])
        print ("")
        print ("")
        

    elif playerOneArmy [a][2] - playerTwoArmy [i][2] == 0:
        print ("_____________________________________________________________")
        print ("|                      Battle Ground                        |")
        print ("_____________________________________________________________")
        print (str(playerOneArmy[a]) + " VS " + str(playerTwoArmy[i]))
        print ("")
        print ("")
        

        while g < 3:
            if playerOneArmy [a][2] != armyPool[g][2]:
                print ("g2 run" + str(g))
                g += 1
            else:
                print (str(playerOneArmy [a]) + " -2 health")
                playerOneArmy [a][1] = playerOneArmy [a][1] - 2
                if playerOneArmy [a][1] <= 0:
                    print (str(playerOneArmy [a]) + "dead")
                    if playerOneMedics >= playerOneArmy [a][2]:
                        playerOneArmy.append(armyPool[g])
                        playerOneMedics -= playerOneArmy [a][2]
                        print ("+++++++++++++++++++++++++")
                        print ("+Unit is saved by medics+")
                        print ("+Medics left: " + str(playerOneMedics) + "       +")
                        print ("+++++++++++++++++++++++++")
                        a += 1
                    else:
                        a += 1
                else:
                    print (str(playerOneArmy [a]) + "still alive")
                
                print (str(playerTwoArmy [i]) + " -2 health")
                playerTwoArmy [i][1] = playerTwoArmy [i][1] - 2
                if playerTwoArmy [i][1] <= 0:
                    print (str(playerTwoArmy [i]) + "dead")
                    if playerTwoMedics >= playerTwoArmy [i][2]:
                        playerTwoArmy.append(armyPool[g])
                        playerTwoMedics -= playerTwoArmy [i][2]
                        print ("+++++++++++++++++++++++++")
                        print ("+Unit is saved by medics+")
                        print ("+Medics left: " + str(playerTwoMedics) + "        +")
                        print ("+++++++++++++++++++++++++")
                        i += 1
                    else:
                        i += 1
                else:
                    print (str(playerTwoArmy [i]) + "still alive")
                break
            
        print ("Player One" + playerOneName + "'s army left:")
        print (playerOneArmy [a:])
        print ("Player Two" + playerTwoName + "'s army left:")
        print (playerTwoArmy [i:])
        print ("")
        print ("")
                
    else:
        print ("_____________________________________________________________")
        print ("|                      Battle Ground                        |")
        print ("_____________________________________________________________")
        print (str(playerOneArmy[a]) + " VS " + str(playerTwoArmy[i]))
        print ("")
        print ("")
        
        
        while g < 3:
            if playerOneArmy [a][2] != armyPool[(g+1)%3][2]:
                print ("g3 run" + str(g))
                g += 1
            else:
                print (str(playerOneArmy [a]) + " -3 health")
                playerOneArmy [a][1] = playerOneArmy [a][1] - 3
                if playerOneArmy [a][1] <= 0:
                    print (str(playerOneArmy [a]) + "dead")
                    if playerOneMedics >= playerOneArmy [a][2]:
                        playerOneArmy.append(armyPool[g%2+1])
                        playerOneMedics -= playerOneArmy [a][2]
                        print ("+++++++++++++++++++++++++")
                        print ("+Unit is saved by medics+")
                        print ("+Medics left: " + str(playerOneMedics) + "         +")
                        print ("+++++++++++++++++++++++++")
                        a += 1
                    else:
                        a += 1
                else:
                    print (str(playerOneArmy [a]) + "still alive")
                
                print (str(playerTwoArmy [i]) + " -1 health")
                playerTwoArmy [i][1] = 0
                print (str(playerTwoArmy [i]) + "dead")
                if playerTwoMedics >= playerTwoArmy [i][2]:
                    playerTwoArmy.append(armyPool[g])
                    playerTwoMedics -= playerTwoArmy [i][2]
                    print ("+++++++++++++++++++++++++")
                    print ("+Unit is saved by medics+")
                    print ("+Medics left: " + str(playerTwoMedics) + "        +")
                    print ("+++++++++++++++++++++++++")
                    i += 1
                else:
                        i += 1
                break
            
        print ("Player One" + playerOneName + "'s army left:")
        print (playerOneArmy [a:])
        print ("Player Two" + playerTwoName + "'s army left:")
        print (playerTwoArmy [i:])
        print ("")
        print ("")
            
    if a == len(playerOneArmy) and i != len(playerTwoArmy):
        print ("*************************************************************")
        print ("Congratulations!")
        print ("Player Two " + playerTwoName + " is the winner")
        print ("*************************************************************")
        break
    elif i == len(playerTwoArmy) and a != len(playerOneArmy):
        print ("*************************************************************")
        print ("Congratulations!")
        print ("Player One " + playerOneName + " is the winner")
        print ("*************************************************************")
        break
    elif a == len(playerOneArmy) and i == len(playerTwoArmy):
        print ("*************************************************************")
        print ("Both of army died, no winner")
        print ("*************************************************************")
# Out:
# Hello, player One, Please enter your name: Yao
# Hello,Yao, you have a total of $10 in your pocket
#
#
# _________________________________________________________________________________________
# |                                      Instruction                                      |
# | Units are purchased and stored in your army                                           |
# | At least you need to purchase one unit for your army.                                 |
# | You can purchase 3 kind of units: Archer, Soldier and Knight                          |
# | Archers are good against Soldiers but are terrible against Knights.                   |
# | Soldiers are good against Knights but can’t win against Archers.                      |
# | Knights beat Archers, but fall short against Soldiers.                                |
# | The winning matrix                                                                    |
# ...
